# %% [markdown]
# # Numpy and pandas

# %%
# %run numpy3.py

# %%
import numpy as np
s=np.random.randn(5,4,2)

# %%
np.mean(s)
# Out:
# 0.1510956112735251

# %%
import random

# %%
position=0
walk=[position]
steps=1000
for i in range(steps):
    step=1 if random.randint(0,1) else -1
    position+=step
    walk.append(position)

# %%
import matplotlib.pyplot as plt
plt.plot(walk[:100])

# %%
import numpy as np
nwalks = 5000
nsteps = 1000
draws = np.random.randint(0, 2, size=(nwalks, nsteps)) # 0或1
steps = np.where(draws > 0, 1, -1)
walks = steps.cumsum(1)
walks
# Out:
# array([[  1,   2,   1, ...,  14,  15,  14],
#        [ -1,  -2,  -3, ...,  20,  19,  18],
#        [  1,   0,  -1, ...,  46,  47,  46],
#        ...,
#        [  1,   2,   1, ...,  10,   9,  10],
#        [  1,   2,   3, ..., -24, -25, -26],
#        [ -1,  -2,  -1, ...,  70,  69,  70]])

# %%
walks.max()
# Out:
# 119

# %% [markdown]
# ## 5.1 pandas

# %%
import pandas as pd

# %%
obj=pd.Series([3,4,5,6,7])

# %%
obj
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %% [markdown]
# 获取值和索引

# %%
obj.values
# Out:
# array([3, 4, 5, 6, 7], dtype=int64)

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=5, step=1)
